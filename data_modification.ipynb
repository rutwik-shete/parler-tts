# %%
from datasets import load_from_disk,load_dataset

raw = load_from_disk("/Users/rutwikshete/Desktop/parler-tts/tmp_expresso")

# %%
raw
# Out:
# Dataset({
#     features: ['text', 'text_original', 'speaker_id', 'path', 'chapter_id', 'id', 'utterance_pitch_mean', 'utterance_pitch_std', 'snr', 'c50', 'speaking_rate', 'phonemes', 'stoi', 'si-sdr', 'pesq', 'noise', 'reverberation', 'speech_monotony', 'sdr_noise', 'pesq_speech_quality', 'input_ids', 'generated_ids'],
#     num_rows: 2
# })

# %%
main_data = load_dataset("blabble-io/libritts_r",'dev')

# %%
main_data['dev.clean'][0]['audio']['array']
# Out:
# array([ 0.        ,  0.        ,  0.        , ..., -0.00326538,
#        -0.00317383, -0.00286865])

# %%
raw = raw.add_column("audio",[main_data['dev.clean'][0]['audio'],main_data['dev.clean'][1]['audio']])

# %%
raw.save_to_disk('./audio_data')
# Out:
# ...
# Saving the dataset (1/1 shards): 100%|██████████| 2/2 [00:00<00:00, 34.00 examples/s]

# %%
raw = load_from_disk("/Users/rutwikshete/Desktop/parler-tts/audio_data")

# %%
raw[0]
# Out:
# {'text': 'The weapon must still have been there.',
#  'text_original': 'The weapon must still have been there.',
#  'speaker_id': 'Speaker 3081',
#  'path': '/root/.cache/huggingface/datasets/downloads/extracted/5551a515e85b9e463062524539c2e1cb52ba32affe128dffd866db0205248bdd/LibriTTS_R/dev-clean/3081/166546/3081_166546_000101_000001.wav',
#  'chapter_id': '166546',
#  'id': '3081_166546_000101_000001',
#  'utterance_pitch_mean': 250.74618530273438,
#  'utterance_pitch_std': 39.03498077392578,
#  'snr': 45.983673095703125,
#  'c50': 59.84812545776367,
#  'speaking_rate': 'moderate speed',
#  'phonemes': 'ðʌ wɛpʌn mʌst stɪl hæv bɪn ðɛɹ.',
#  'stoi': 0.9919637441635132,
#  'si-sdr': 28.88978385925293,
#  'pesq': 3.93467116355896,
#  'noise': 'balanced in clarity',
#  'reverberation': 'very close-sounding',
#  'speech_monotony': 'monotone',
#  'sdr_noise': 'very clear',
#  'pesq_speech_quality': 'great speech quality',
# ...
